# %%
# Import required modules
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # Проанализируем данные

# %%
df = pd.read_csv('character-deaths.csv')

# %%
ful = pd.read_csv('character-predictions.csv')

# %% [markdown]
# ## Убираем шум из данных

# %%
def fix_house(allegiances):
    if 'House' in allegiances:
        return allegiances.replace('House ', '')
    return allegiances

# %%
df['Allegiances'] = df['Allegiances'].apply(fix_house)

# %% [markdown]
# ## Объединить данные двух таблиц

# %%
ful_dat = df.join(ful.set_index('name'), on='Name')

# %% [markdown]
# ## Убираем строки по которым нету актуальных данных

# %%
pure = ful_dat.loc[ful_dat['actual'].notnull()]

# %%
pure = ful_dat.loc[ful_dat['actual'] > 0]

# %%
len(pure.index)
# Out:
# 591

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = pure.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %% [markdown]
# ## Убираем сомнительные колонки

# %%
pure = pure.drop(columns=['Death Year', 'mother', 'father', 'heir', 'actual',
                            'isAliveMother', 'isAliveFather', 'isAliveHeir',
                            'age', 'house', 'S.No', 'dateOfBirth', 'spouse',
                            'isAliveSpouse', 'isMarried', 'male', 'culture',
                            'isNoble', 'alive', 'DateoFdeath', 'isAlive',
                            'numDeadRelations', 'boolDeadRelations', 'isPopular',
                            'Book of Death',
                            'Death Chapter', 'Book Intro Chapter', 'plod', 'title',
#                           'GoT', 'CoK', 'SoS', 'FfC', 'DwD', 'popularity',
                            'book1', 'book2', 'book3', 'book4', 'book5'])

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = pure.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %%
pure.head()
# Out:
#               Name    Allegiances  Gender  Nobility  GoT  CoK  SoS  FfC  DwD  \
# 0   Addam Marbrand      Lannister       1         1    1    1    1    1    0
# 4   Aemon Costayne      Lannister       1         1    0    0    1    0    0
# 5  Aemon Estermont      Baratheon       1         1    0    1    1    0    0
# 8    Aeron Greyjoy        Greyjoy       1         1    0    1    0    1    0
# 9           Aethan  Night's Watch       1         0    0    0    1    0    0
#
#    pred  popularity
# 0   0.0    0.130435
# 4   1.0    0.010033
# 5   1.0    0.030100
# 8   0.0    0.458194
# 9   1.0    0.010033

# %%
pure.describe()
# Out:
#            Gender    Nobility         GoT         CoK         SoS         FfC  \
# count  591.000000  591.000000  591.000000  591.000000  591.000000  591.000000
# mean     0.803723    0.507614    0.233503    0.324873    0.433164    0.351946
# std      0.397517    0.500366    0.423418    0.468724    0.495933    0.477982
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    0.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               DwD        pred  popularity
# count  591.000000  591.000000  591.000000
# mean     0.319797    0.720812    0.115467
# std      0.466793    0.448980    0.197317
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.016722
# ...

# %% [markdown]
# ## Предсказание смерти сгруппированных по именным домам

# %%
pure[pure['pred'] == 1]['Allegiances'].value_counts().plot(kind='bar')

# %% [markdown]
# Как видно, если персонаж не принадлежит никакому дому, то скорее всего он умрёт :)

# %% [markdown]
# ## Имеет ли значение принадлежность к знатному дому?

# %%
pure[pure['pred'] == 1]['Nobility'].value_counts().plot(kind='bar')

# %% [markdown]
# ## Кто умирает чаще мужчина или женщина?

# %%
pure[pure['pred'] == 1]['Gender'].value_counts().plot(kind='bar')

# %% [markdown]
# Мужчины умирают гораздо чаще, чем женщины

# %% [markdown]
# ## Подготовка данных для обучения модели

# %%
x = pure.drop(columns=['pred', 'Name'])
y = pure['pred'].copy()
y = y.astype('int64')

# %%
x = pd.get_dummies(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train.head()
# Out:
#      Gender  Nobility  GoT  CoK  SoS  FfC  DwD  popularity  Allegiances_Arryn  \
# 773       1         1    0    0    0    1    0    0.030100                  0
# 843       1         0    1    0    0    0    0    0.006689                  0
# 407       1         1    0    0    0    0    1    0.719064                  0
# 644       1         0    1    1    0    0    0    0.010033                  0
# 772       1         0    0    0    0    0    1    0.016722                  0
#
#      Allegiances_Baratheon  Allegiances_Greyjoy  Allegiances_Lannister  \
# 773                      0                    0                      1
# 843                      0                    0                      0
# 407                      0                    0                      0
# 644                      0                    0                      0
# 772                      0                    0                      0
#
# ...

# %%
y_train.head()
# Out:
# 773    1
# 843    1
# 407    1
# 644    0
# 772    1
# Name: pred, dtype: int64

# %%
models = []
acc = []
models.append(RandomForestClassifier(n_estimators=25))
models.append(SVC(gamma='scale', decision_function_shape='ovo'))
models.append(KNeighborsClassifier(n_neighbors=3))

# %%
for m in models:
    m.fit(x_train, y_train)
    y_pred = m.predict(x_test)
    acc.append(accuracy_score(y_test, y_pred))

# %% [markdown]
# ## Результат

# %%
sm = pd.Series(acc)
sm.plot(kind='bar')
